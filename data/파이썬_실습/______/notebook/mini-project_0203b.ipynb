# %% [markdown]
# ### 전자 계산기를 만들어 보자.
# #### calculate 란는 함수를 만들어 본다.
# #### 출력 예:
# calculate(1, 1, '+') <br>
# 2 <br>
# <br>
# calculate(2, 3, '$*$') <br>
# 6

# %%
def calculate(x=0,y=0,opr='+'):
#
#     ????
#

# %% [markdown]
# #### 이제는 함수를 사용해 보시오.

# %%
calculate(2,3, '+')

# %%
calculate(5,6, '*')

# %%
calculate(8,2, '/')

# %%
calculate(2,3, '^')

# %%
calculate()
